# %%
import pandas as pd
import json

# %%
#with open("goodreads_interactions_mystery_thriller_crime.json", "r") as read_file:
books = 'goodreads_books_mystery_thriller_crime.json'
interactions = []
file = "goodreads_interactions_mystery_thriller_crime.json"
counter = 0
for line in open(file, mode="r"):
    interactions.append(json.loads(line))
    counter += 1
    if counter == 100:
        break

# %%
len(interactions)
# Out:
# 24862043

# %%
interaction_df = pd.DataFrame(interactions)

# %%
interaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
# book_id         100 non-null object
# date_added      100 non-null object
# date_updated    100 non-null object
# isRead          100 non-null bool
# rating          100 non-null int64
# read_at         100 non-null object
# review_id       100 non-null object
# started_at      100 non-null object
# user_id         100 non-null object
# dtypes: bool(1), int64(1), object(7)
# memory usage: 6.4+ KB

# %%
interaction_df.head()
# Out:
#     book_id                      date_added                    date_updated  \
# 0   6392944  Mon Jul 24 02:48:17 -0700 2017  Sun Jul 30 09:28:03 -0700 2017
# 1   2279538  Wed Mar 29 00:27:14 -0700 2017  Wed Mar 29 00:27:14 -0700 2017
# 2  20821043  Mon Mar 27 22:52:11 -0700 2017  Mon Mar 27 22:52:12 -0700 2017
# 3  31184479  Fri Jan 06 16:22:46 -0800 2017  Fri Jan 06 16:22:46 -0800 2017
# 4  28684704  Tue Nov 15 11:29:22 -0800 2016  Mon Mar 20 23:40:27 -0700 2017
#
#    isRead  rating                         read_at  \
# 0    True       3  Tue Jul 25 00:00:00 -0700 2017
# 1   False       0
# 2   False       0
# 3   False       0
# 4    True       3  Sat Mar 18 23:22:42 -0700 2017
#
#                           review_id                      started_at  \
# 0  a5ae9eb634692c22930ee6b929e46495  Mon Jul 24 00:00:00 -0700 2017
# 1  3c8093ed2cdda654afb47c04c38d9732
# 2  27ab15b4cb44919d92760b2c886290eb
# 3  ccf3e5177da4b4e553e74f954ff461e9
# ...

# %%
#with open("goodreads_interactions_mystery_thriller_crime.json", "r") as read_file:
books = 'goodreads_books_mystery_thriller_crime.json'
book_data = []
interactions = "goodreads_interactions_mystery_thriller_crime.json"
for line in open(books, mode="r"):
    book_data.append(json.loads(line))

# %%
len(book_data)
# Out:
# 219235

# %%
df = pd.DataFrame(book_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219235 entries, 0 to 219234
# Data columns (total 27 columns):
# asin                   219235 non-null object
# authors                219235 non-null object
# average_rating         219235 non-null object
# book_id                219235 non-null object
# country_code           219235 non-null object
# description            219235 non-null object
# edition_information    219235 non-null object
# format                 219235 non-null object
# image_url              219235 non-null object
# is_ebook               219235 non-null object
# isbn                   219235 non-null object
# isbn13                 219235 non-null object
# kindle_asin            219235 non-null object
# language_code          219235 non-null object
# link                   219235 non-null object
# num_pages              219235 non-null object
# popular_shelves        219235 non-null object
# publication_day        219235 non-null object
# ...

# %%
df.head()
# Out:
#          asin                                            authors  \
# 0                           [{'author_id': '37778', 'role': ''}]
# 1  B01NCIKAQX              [{'author_id': '242185', 'role': ''}]
# 2  B01ALOWJN0  [{'author_id': '15104629', 'role': ''}, {'auth...
# 3                          [{'author_id': '190988', 'role': ''}]
# 4              [{'author_id': '337108', 'role': ''}, {'author...
#
#   average_rating   book_id country_code  \
# 0           3.93   6066814           US
# 1           4.33  33394837           US
# 2           3.49  29074697           US
# 3           3.30   1902202           US
# 4           3.54   9671977           US
#
#                                          description edition_information  \
# 0  London, 1196. At the command of Richard the Li...
# 1
# 2  <b>BATHS, BANKS AND ROMAN INSURRECTION</b> <br...
# 3  Gerald breezily introduced his wife, Helen, to...         Large Print
# 4  "I misteri di Eleusi" e il quinto romanzo di A...
#
# ...

# %%
file = "goodreads_book_genres_initial.json"
genre_raw = []

for line in open(file, mode="r"):
    genre_raw.append(json.loads(line))

# %%
genre_df = pd.DataFrame(genre_raw)

# %%
genre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2360655 entries, 0 to 2360654
# Data columns (total 2 columns):
# book_id    object
# genres     object
# dtypes: object(2)
# memory usage: 36.0+ MB

# %%
genre_df.head()
# Out:
#    book_id                                             genres
# 0  5333265      {'history, historical fiction, biography': 1}
# 1  1333909  {'fiction': 219, 'history, historical fiction,...
# 2  7327624  {'fantasy, paranormal': 31, 'fiction': 8, 'mys...
# 3  6066819  {'fiction': 555, 'romance': 23, 'mystery, thri...
# 4   287140                                 {'non-fiction': 3}

# %%
genre_df['genres'].value_counts(dropna=False)

# %%
books_works = []
file = "goodreads_book_works.json"
for line in open(file, mode="r"):
    books_works.append(json.loads(line))

# %%
works = pd.DataFrame(books_works)

# %%
works.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1521962 entries, 0 to 1521961
# Data columns (total 17 columns):
# best_book_id                         1521962 non-null object
# books_count                          1521962 non-null object
# default_chaptering_book_id           1521962 non-null object
# default_description_language_code    1521962 non-null object
# desc_user_id                         1521962 non-null object
# media_type                           1521962 non-null object
# original_language_id                 1521962 non-null object
# original_publication_day             1521962 non-null object
# original_publication_month           1521962 non-null object
# original_publication_year            1521962 non-null object
# original_title                       1521962 non-null object
# rating_dist                          1521962 non-null object
# ratings_count                        1521962 non-null object
# ...

# %%
works.head()
# Out:
#   best_book_id books_count default_chaptering_book_id  \
# 0      5333265           1
# 1        25717          22
# 2      7327624           2
# 3      6066819          38
# 4       287140           2
#
#   default_description_language_code desc_user_id media_type  \
# 0                                        1015035       book
# 1                                                      book
# 2                                         171430       book
# 3                                        7492276       book
# 4                                            -30       book
#
#   original_language_id original_publication_day original_publication_month  \
# 0                                                                        8
# 1
# 2
# 3                                            14                          7
# 4
#
#   original_publication_year  \
# 0                      1984
# 1                      2001
# 2                      1987
# 3                      2009
# ...
